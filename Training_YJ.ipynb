# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.3.0'

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = '1'

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
! python3 train_Last.py \
  --imagenet_checkpoint=resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5 \
  --logdir=Yonsei_Last_0124/
# Out:
# 2021-01-24 02:05:54.631514: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# I0124 02:05:56.954594 140140852705024 train_Last.py:140] Running training script with
#
# I0124 02:05:56.954777 140140852705024 train_Last.py:141] logdir= Yonsei_Last_0124/
# I0124 02:05:56.955451 140140852705024 train_Last.py:142] initial_lr= 0.010000
# I0124 02:05:56.955536 140140852705024 train_Last.py:143] block3_strides= True
# 2021-01-24 02:05:56.956664: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-01-24 02:05:56.971458: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:61:00.0 name: Quadro RTX 5000 computeCapability: 7.5
# coreClock: 1.815GHz coreCount: 48 deviceMemorySize: 15.72GiB deviceMemoryBandwidth: 417.29GiB/s
# ...

# %%
acc= [0.013690, 0.013297, 0.063084, 0.198293, 0.244721, 0.510332, 0.469890, 0.646249, 0.561444,
      0.655020, 0.724742, 0.786456, 0.812275, 0.775157, 0.743845, 0.803695, 0.837949, 0.841757, 
      0.860568, 0.870013, 0.878021, 0.895328, 0.866835, 0.878122, 0.876393, 0.869935, 0.915566, 
      0.930627, 0.915813, 0.916071, 0.903324, 0.928695, 0.935490, 0.922035, 0.937882, 0.945519, 
      0.945923, 0.948562, 0.936759, 0.948753, 0.943228, 0.951505, 0.948574, 0.955458, 0.947799, 
      0.956907, 0.954818, 0.954436, 0.955469, 0.951516]

# %%
val = [0.012522, 0.048911, 0.225517, 0.302594, 0.384423, 0.557615, 0.416285, 0.486916, 0.755773, 
       0.159748, 0.380660, 0.632233, 0.650977, 0.597372, 0.736062, 0.694003, 0.845418, 0.844721, 
       0.843947, 0.854784, 0.888118, 0.897619, 0.894733, 0.907367, 0.891700, 0.915645, 0.939050, 
       0.932918, 0.935119, 0.933614, 0.939218, 0.934018, 0.939027, 0.940622, 0.941004, 0.949427, 
       0.943969, 0.949686, 0.941566, 0.950371, 0.934041, 0.949360, 0.955717, 0.958985, 0.954178, 
       0.948776, 0.958603, 0.953190, 0.952257, 0.952403]

# %%
#acc=[0.003333,0.009583,0.014444,0.029306,0.026806,0.087222,0.345556,
     0.494444,0.710972,0.826944,
     0.695694,0.767917,0.805972,0.785833,0.731528,0.840833,0.890972, 0.801667,
     0.884306,0.884583,0.896111,0.908472,0.889861,0.921667,0.905972,0.908611,0.935139,
     0.934306,0.947917,0.928472,0.952222,0.959028,0.952083,0.951528,0.953750,0.961528,0.966528,
     0.964167,0.961250,0.962500,0.966389,0.967361,0.973194,0.971389,0.97236]

# %%
acc_=[a*100 for a in acc]
val_=[a*100 for a in val]

# %%
x =[i for i in range(10000,510000,10000)]
len(x)
# Out:
# 50

# %%
from matplotlib import pyplot as plt
 
plt.plot(x, acc_,'b')
plt.plot(x, val_,'g')
plt.xlabel('# of iter')
plt.ylabel('accuracy (%)')
plt.legend(['descriptor','attention'])
plt.show()

# %%
# !python3 /home/smart02/LM/research/delf/delf/python/training/model/export_local_model.py \
  --ckpt_path=/home/smart02/LM/research/delf/delf/python/training/Landmark_Last_training_/delf_weights\
  --export_path=/home/smart02/LM/research/delf/delf/python/training/model_0126 \
  --block3_strides
# Out:
# 2021-01-26 15:48:40.731123: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-26 15:48:42.810252: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-01-26 15:48:42.824860: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:61:00.0 name: Quadro RTX 5000 computeCapability: 7.5
# coreClock: 1.815GHz coreCount: 48 deviceMemorySize: 15.72GiB deviceMemoryBandwidth: 417.29GiB/s
# 2021-01-26 15:48:42.824912: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-26 15:48:42.826337: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# ...

# %%
#test model

# %%
/home/smart02/Final_dataset/index/4.19학생혁명기념탑/4.19학생혁명기념탑_001.JPG
/home/smart02/Final_dataset/index/4.19학생혁명기념탑/4.19학생혁명기념탑_120.JPG

# %%
/home/smart02/Final_dataset/index/금암기적비/금암기적비_062.JPG
/home/smart02/Final_dataset/index/금암기적비/금암기적비_063.JPG

# %%
# !python3 ../examples/extract_features.py \
  --config_path ../examples/delf_config_example2_sample_test.pbtxt \
  --list_images_path list_images.txt \
  --output_dir ./oxford5k_features
# Out:
# 2020-12-22 17:22:47.409218: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Reading list of images...
# done! Found 2 images
# 2020-12-22 17:22:49.473997: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-22 17:22:49.490839: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:61:00.0 name: Quadro RTX 5000 computeCapability: 7.5
# coreClock: 1.815GHz coreCount: 48 deviceMemorySize: 15.72GiB deviceMemoryBandwidth: 417.29GiB/s
# 2020-12-22 17:22:49.490927: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-22 17:22:49.493989: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# ...

# %%
# !python3 ../examples/match_images.py \
  --image_1_path /home/smart02/Final_dataset/index/금암기적비/금암기적비_062.JPG \
  --image_2_path /home/smart02/Final_dataset/index/금암기적비/금암기적비_063.JPG \
  --features_1_path /home/smart02/LM/research/delf/delf/python/training/oxford5k_features/금암기적비_062.delf \
  --features_2_path /home/smart02/LM/research/delf/delf/python/training/oxford5k_features/금암기적비_063.delf \
  --output_image matched_images_ga.png
# Out:
# 2020-12-22 17:26:53.450697: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Loaded image 1's 911 features
# Loaded image 2's 1000 features
# Found 214 inliers

# %%
image_paths=['/home/smart02/Final_dataset/index/4.19학생혁명기념탑/4.19학생혁명기념탑_001.JPG','/home/smart02/Final_dataset/index/4.19학생혁명기념탑/4.19학생혁명기념탑_120.JPG']

# %%
import tensorflow as tf
from delf.python.detect_to_retrieve import dataset
import os
from delf import utils

# %%
_,index_list,_,_,index_lm_names = dataset.ReadDatasetFile('/home/smart02/DELF_TEST/models/research/delf/delf/python/detect_to_retrieve/final_dataset_for_retrieval/')

# %%
import numpy as np

# %%
image_paths_ = []
for i in range(len(index_list)):
    image_paths = os.path.join('/home/smart02/Final_dataset/index/', index_lm_names[i] + '/' + index_list[i])
#         image_paths = os.path.join(cmd_args.images_dir + '/' + index_list[i])
    image_paths_.append(image_paths)

# %%
image_paths_[1]
# Out:
# '/home/smart02/Final_dataset/index/4.19학생혁명기념탑/4.19학생혁명기념탑_002.JPG'

# %%
pil_im = utils.RgbLoader(image_paths_[1])

# %%
im = np.array(pil_im)

# %%
print(type(im[0][0][0]))
# Out:
# <class 'numpy.uint8'>

# %%
im_re = np.expand_dims(im, axis = 0)
print(im_re.shape)
# Out:
# (1, 540, 960, 3)

# %%
print(type(im_re[0][0][0][0]))
# Out:
# <class 'numpy.uint8'>

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import os
import sys
import time

import numpy as np
from six.moves import range
import tensorflow as tf

from google.protobuf import text_format
from tensorflow.python.platform import app
from delf import delf_config_pb2
from delf import feature_io
from delf import utils
from delf import extractor

# %%
config = delf_config_pb2.DelfConfig()
with tf.io.gfile.GFile('/home/smart02/DELF_TEST/models/research/delf/delf/python/detect_to_retrieve/delf_gld_config.pbtxt', 'r') as f:
    text_format.Merge(f.read(), config)

extractor_fn = extractor.MakeExtractor(config)

# %%
extracted_features = extractor_fn(im)
locations_out = extracted_features['local_features']['locations']
descriptors_out = extracted_features['local_features']['descriptors']
feature_scales_out = extracted_features['local_features']['scales']
attention_out = extracted_features['local_features']['attention']


print(descriptors_out.shape)
print(attention_out.shape)
print(feature_scales_out.shape)
print(locations_out.shape)
# Out:
# shape of image before resizing: (540, 960, 3)
# shape of image after resizing: (540, 960, 3)
# (1000, 128)
# (1000,)
# (1000,)
# (1000, 2)

# %%
attention = AttentionModel(name='attention')
feat, prob, score = attention(im_re)
# Out:
# input image size:  (1, 540, 960, 3)
# prob size:  (1, 540, 960, 1)
# Feature from Attention model size:  (1, 3)

# %%
model = tf.saved_model.load('/home/smart02/LM/research/delf/delf/python/training/exported_nes_f')

# %%
predict = model.signatures['serving_default']

# %%
config = delf_config_pb2.DelfConfig()

# %%
# !pwd
# Out:
# /home/smart02/LM/research/delf/delf/python/training

# %%
# !zip training.zip -r /home/smart02/LM/research/delf/delf/python/training/exported_nes_f
# Out:
#   adding: home/smart02/LM/research/delf/delf/python/training/exported_nes_f/ (stored 0%)
#   adding: home/smart02/LM/research/delf/delf/python/training/exported_nes_f/assets/ (stored 0%)
#   adding: home/smart02/LM/research/delf/delf/python/training/exported_nes_f/saved_model.pb (deflated 92%)
#   adding: home/smart02/LM/research/delf/delf/python/training/exported_nes_f/variables/ (stored 0%)
#   adding: home/smart02/LM/research/delf/delf/python/training/exported_nes_f/variables/variables.index (deflated 78%)
#   adding: home/smart02/LM/research/delf/delf/python/training/exported_nes_f/variables/variables.data-00000-of-00001 (deflated 7%)
