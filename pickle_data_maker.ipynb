# %%
# !python3 query_index_groundtruth_data_maker.py \
  --first_image_file_type='query' \
  --second_image_file_type='index' \
  --dataset_file_path=/home/smart02/Last_Dataset/ \
  --output_directory=/home/smart02/Last_Dataset/all_data_from_py_code/


#   --image_file_type='query' \
# Out:
# 2021-01-27 21:12:49.631798: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# [{'힐탑호텔_036.jpg': array([450677, 450678, 450679, 450680, 450681, 450682, 450683, 450684,
#        450685, 450686, 450687, 450688, 450689, 450690, 450691, 450692,
#        450693, 450694, 450695, 450696, 450697, 450698, 450699, 450700,
#        450701, 450702, 450703, 450704, 450705, 450706, 450707, 450708,
#        450709, 450710, 450711, 450712, 450713, 450714, 450715, 450716,
#        450717, 450718, 450719, 450720, 450721, 450722, 450723, 450724,
#        450725, 450726, 450727, 450728, 450729, 450730, 450731, 450732,
#        450733, 450734, 450735, 450736, 450737, 450738, 450739, 450740,
#        450741, 450742, 450743, 450744, 450745, 450746, 450747, 450748,
#        450749, 450750, 450751, 450752, 450753, 450754, 450755, 450756,
#        450757, 450758, 450759, 450760, 450761, 450762, 450763, 450764,
# ...
